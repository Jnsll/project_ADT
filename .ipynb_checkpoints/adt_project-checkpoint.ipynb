# %%
#!/usr/bin/python
#coding: utf-8

import re, glob
dirname='/media/DATA/Master/Analyse_donnees_text/data_suj1/train/'
d_entities={}
files=glob.glob(dirname+'*.ent')
for file in files:
    with open(file, 'r') as f_in :
        for line in f_in :
            line = re.sub(r'\n', '', line)
            numId = re.sub(r"(.+)\t([A-Z][a-z]+)\t(.+)", r'\1', line)
            cat = re.sub(r"(.+)\t([A-Z][a-z]+)\t(.+)", r'\2', line)
            nom = re.sub(r"(.+)\t([A-Z][a-z]+)\t([0-9]+-[0-9]+) ([A-Za-z]+)", r'\4', line)
            if re.match(r"[0-9]+", numId) and nom not in d_entities:
                d_entities[nom]=cat
#print(d_entities)

# %%
import re, glob
dirname='/media/DATA/Master/Analyse_donnees_text/data_suj1/train/'
d_entities={}
p=re.compile(r'\d+\t([A-Za-z]+)\s\d+-\d+\s([A-Za-z ]+)(\s\d+-\d+\s([A-Za-z ]+))?')

files=glob.glob(dirname+'*.ent')
for file in files:
    with open(file, 'r') as fichier:
        for line in fichier:
            m=p.match(line)
            if not m: break; 
            cat = m.group(1)
            nom = m.group(2)
            if nom not in d_entities:
                d_entities[nom]=cat
            if m.group(4) is not None and m.group(4) not in d_entities:
                d_entities[m.group(4)]=cat
                
print(d_entities)
# Out:
# {'Paenibacillus': 'Bacteria', 'Fluid': 'HostPart', 'light': 'HostPart', 'immunodeficient hosts': 'Host', 'Ticks': 'Host', 'grapes': 'Host', 'vaccines': 'Medical', 'ticks': 'Host', 'tropical Asian countries': 'Geographical', 'Clavibacter michiganensis': 'Bacteria', 'Clone C': 'Bacteria', 'compromised hosts': 'Host', 'Camponotus': 'Host', 'small ruminants': 'Host', 'LB': 'Bacteria', 'Borrelia garinii PBi': 'Bacteria', 'pulmonary': 'HostPart', 'Mediavalis': 'Bacteria', 'deep': 'Environment', 'warm': 'Host', 'Mycobacterium tuberculosis complex': 'Bacteria', 'fat body of the insect': 'HostPart', 'dust particles': 'Environment', 'terrestrial habitats': 'Environment', 'Florida Keys': 'Geographical', 'Clavibacter': 'Bacteria', 'lymph nodes': 'HostPart', 'North America': 'Geographical', 'salmonides': 'Host', 'urogenital tracts of humans': 'HostPart', 'soil rhizosphere': 'Soil', 'Bacillus cereus': 'Bacteria', 'Lake Khatyn': 'Geographical', 'Drosophila': 'Host', 'products': 'Food', 'Sheath': 'HostPart', 'tropical areas of the world': 'Environment', 'jejunum in the small intestines': 'HostPart', 'Ornithodoros turicatae': 'Host', 'Canada': 'Geographical', 'host cell': 'HostPart', 'phytopathogenic': 'Host', 'outer membrane': 'HostPart', 'rhizosphere of plants': 'HostPart', 'epsilonproteobacteria': 'Bacteria', 'Xac': 'Bacteria', 'insidiosus': 'Bacteria', 'Orientalis': 'Bacteria', 'VEB': 'Bacteria', 'spirochaete': 'Bacteria', 'People': 'Host', 'boils': 'HostPart', 'aquatic environments': 'Water', 'Pulmonary': 'HostPart', 'community': 'Host', 'brain abscess': 'HostPart', 'bones': 'HostPart', 'hot springs': 'Water', 'PsJN': 'Bacteria', 'Bordetella petrii DSM ': 'Bacteria', 'Xanthomonas campestris': 'Bacteria', 'Vibrio': 'Bacteria', 'kidneys': 'HostPart', 'abattoir workers': 'Host', 'biofuel': 'Environment', 'biofilms': 'Environment', 'aqueous': 'Water', 'breaks in the skin': 'HostPart', 'semidefined solid medium containing already enzimatically digested proteins': 'Environment', 'ants': 'Host', 'Enterobacteriaceae': 'Bacteria', 'high temperature equipment': 'Environment', 'mammalian': 'Host', 'zones': 'Environment', 'mycoplasmal': 'Bacteria', 'heavy metals': 'Environment', 'cellulose': 'Environment', 'endosymbiont of the tsetse fly': 'HostPart', 'Burkholderia phytofirmans strain PsJN T': 'Bacteria', 'tsetse immune system': 'HostPart', 'bite of the brown dog tick': 'HostPart', 'Spiroplasma citri': 'Bacteria', 'rodent': 'Host', 'chlorosomes': 'HostPart', 'Thiobacillus ferrooxidans': 'Bacteria', 'nematodes': 'Host', 'bifidobacteria': 'Bacteria', 'Burkholderia multivorans ATCC ': 'Bacteria', 'Russia': 'Geographical', 'yeast extract': 'Environment', 'Mauritius': 'Geographical', 'earth': 'Soil', 'arthropod': 'Host', 'French hospital': 'Medical', 'GPE PC': 'Bacteria', 'GSB': 'Bacteria', 'spirochetes': 'Bacteria', 'Burkholderia': 'Bacteria', 'Mycoplasma genitalium': 'Bacteria', 'respiratory therapy items': 'Medical', 'corn': 'Host', 'domestic animals': 'Host', 'adult': 'Host', 'vascular tissue': 'HostPart', 'USA': 'Geographical', 'terrestrial crustaceans': 'Host', 'animal tissue': 'HostPart', 'rhizobium': 'Bacteria', 'Hungary': 'Geographical', 'Xanthomonas': 'Bacteria', 'cells': 'HostPart', 'ABF pigs': 'Host', 'Gram positive bacterium with a low G ': 'Bacteria', 'graft recipients': 'Host', 'Rickettsiales': 'Bacteria', 'bacterial taxon': 'Bacteria', 'Humans': 'Host', 'cattle': 'Host', 'nosocomial': 'Medical', 'skin': 'HostPart', 'offspring of uninfected females': 'Host', 'cavity': 'HostPart', 'cellularly': 'HostPart', 'arthropods': 'Host', 'membrane': 'HostPart', 'digestive tract': 'HostPart', 'healthy individuals': 'Host', 'Salmonella spp': 'Bacteria', 'Genoscope': 'Geographical', 'Ethiopia': 'Geographical', 'sugar cane': 'Host', 'E': 'Bacteria', 'Mycobacterium tuberculosis': 'Bacteria', 'Mars': 'Geographical', 'S': 'Bacteria', 'citrus leaf miner': 'Host', 'Toulouse Genopole': 'Geographical', 'contaminated milk': 'Food', 'infant': 'Host', 'Streptococci ...
