# %%
#!/usr/bin/python
#coding: utf-8

#import re, glob
#dirname='/media/DATA/Master/Analyse_donnees_text/data_suj1/train/'
#d_entities={}
#files=glob.glob(dirname+'*.ent')
#for file in files:
#    with open(file, 'r') as f_in :
#        for line in f_in :
#            line = re.sub(r'\n', '', line)
#            numId = re.sub(r"(.+)\t([A-Z][a-z]+)\t(.+)", r'\1', line)
#            cat = re.sub(r"(.+)\t([A-Z][a-z]+)\t(.+)", r'\2', line)
#            nom = re.sub(r"(.+)\t([A-Z][a-z]+)\t([0-9]+-[0-9]+) ([A-Za-z]+)", r'\4', line)
#            if re.match(r"[0-9]+", numId) and nom not in d_entities:
#                d_entities[nom]=cat
#print(d_entities)

# %%
import re, glob, nltk
from nltk.tokenize import sent_tokenize, word_tokenize
dirname='/media/DATA/Master/Analyse_donnees_text/data_suj1/'
d_entities={}
p=re.compile(r'\d+\t([A-Za-z]+)\s\d+-\d+\s([A-Za-z ]+)(\s\d+-\d+\s([A-Za-z ]+))?')

files=glob.glob(dirname+'train/*.ent')
for file in files:
    with open(file, 'r') as fichier:
        for line in fichier:
            m=p.match(line)
            if not m: break
            cat = m.group(1)
            nom = m.group(2)
            if cat =='Bacteria': continue
            #if nom not in d_entities:
            mots=word_tokenize(nom, 'english')
            #print(len(tuple(mots)))
            d_entities[tuple(mots)]=cat
            if m.group(4) is not None: # En cas de deux entites sur la meme ligne 
                d_entities[tuple(word_tokenize(m.group(4), 'english'))]=cat
                
#print(d_entities)
annotation=[]
file='/media/DATA/Master/Analyse_donnees_text/data_suj1/dev/BTID-10095.txt'
with open(file, 'r') as fichier:
    text=fichier.read()
    words=word_tokenize(text, 'english')
#print(words)
for z in range(len(words)):
    #print('z' + str(z))
    for entity in d_entities:
        #print(entity)
        if len(words)-z-1<len(entity)-1: continue
        if words[z]!= entity[0]: continue
        detect=True
        for i in range(1,len(entity)):
            #print('i :' + str(i))
            #print(entity[i])
            if words[z+i] != entity[i]: 
                detect=False
                break
        if detect:
            annotation.append([d_entities[entity], ' '.join(entity)])
            z=z+len(entity)
            #print('z new:' + str(z))
    
print(annotation)
# Out:
# {('coral',): 'Host', ('urinary',): 'HostPart', ('infected', 'plant', 'material'): 'HostPart', ('homeless', 'people', 'living', 'in', 'France'): 'Host', ('illuminated',): 'Water', ('US', 'dairy', 'cattle'): 'Host', ('photosynthetic', 'apparatus'): 'HostPart', ('North', 'Carolina', 'State', 'University'): 'Geographical', ('water',): 'Water', ('human',): 'Host', ('chlorosomes',): 'HostPart', ('Boyce', 'Thompson', 'Institute', 'for', 'Plant', 'Research'): 'Geographical', ('boils',): 'HostPart', ('patients', 'with', 'cystic', 'fibrosis'): 'Host', ('Birds', 'that', 'are', 'feeding', 'on', 'invertebrates'): 'Host', ('tissue',): 'HostPart', ('spiders',): 'Host', ('raw', 'food'): 'Food', ('grapevines',): 'Host', ('alpha',): 'Environment', ('flagella',): 'HostPart', ('Pulmonary',): 'HostPart', ('North', 'America'): 'Geographical', ('grapevine',): 'Host', ('Western', 'hemisphere'): 'Geographical', ('gut',): 'HostPart', ('urinary', 'tract'): 'HostPart', ('subtropical', 'areas'): 'Environment', ('Japan',): 'Geographical', ('stagnant', 'water'): 'Water', ('children', 'under', 'the', 'age', 'of', 'five'): 'Host', ('California',): 'Geographical', ('Fluid',): 'HostPart', ('bobtail', 'squid'): 'Host', ('abdominal',): 'HostPart', ('cut',): 'HostPart', ('mosquitoes',): 'Host', ('Mars',): 'Geographical', ('genital',): 'HostPart', ('brown', 'dog', 'tick'): 'Host', ('endosymbionts', 'for', 'the', 'tsetse', 'fly'): 'HostPart', ('tsetse', 'fly'): 'Host', ('resistant', 'varieties', 'of', 'sugar', 'cane'): 'Host', ('enteroinvasive',): 'HostPart', ('mammalian',): 'Host', ('Hong', 'Kong'): 'Geographical', ('person',): 'Host', ('murine',): 'Host', ('mulberry',): 'Host', ('lymphatic', 'system'): 'HostPart', ('filaments',): 'HostPart', ('micro',): 'Host', ('elongated', 'cells'): 'HostPart', ('animal', 'intestines'): 'HostPart', ('CBiB',): 'Geographical', ('skin',): 'HostPart', ('equipment',): 'Environment', ('Propella', 'biofilm', 'reactor'): 'Environment', ('patient', 'with', 'neuroborreliosis'): 'Host', ('gas', 'vesicles'): 'HostPart', ('intestinal', 'epithelium'): 'HostPart', ('males',): 'Host', ('NY',): 'Geographical', ('oxic',): 'Water', ('maple',): 'Host', ('phytopathogenic',): 'Host', ('paper', 'mill', 'slimes'): 'Environment', ('areas', 'with', 'high', 'sulfur', 'and', 'salt', 'concentrations'): 'Environment', ('Cutaneous',): 'HostPart', ('person', 'with', 'untreated', 'pulmonary', 'TB'): 'Host', ('chlorosome',): 'HostPart', ('fishes',): 'Host', ('mammary',): 'HostPart', ('atmospheric',): 'Environment', ('chicken',): 'Food', ('microbial',): 'Host', ('termite', 'gut'): 'HostPart', ('ovoid', 'bodies', 'surrounded', 'by', 'a', 'lipid', 'monolayer', 'and', 'filled', 'with', 'more', 'than'): 'HostPart', ('innate',): 'HostPart', ('freshwater',): 'Water', ('coffee',): 'Host', ('lymphatics',): 'HostPart', ('US', 'states'): 'Geographical', ('citrus',): 'Host', ('heavy', 'metals'): 'Environment', ('tissues', 'of', 'ancient', 'mummies'): 'Environment', ('respiratory', 'tree'): 'HostPart', ('raw',): 'Food', ('of', 'ponds'): 'Environment', ('Aedes', 'albopictus'): 'Host', ('branchial',): 'HostPart', ('animal', 'probiotics'): 'Food', ('milk', 'industry'): 'Environment', ('spores',): 'HostPart', ('areas', 'where', 'filariasis', 'is', 'common'): 'Environment', ('splenic', 'abscess'): 'HostPart', ('intestinal', 'tract', 'of', 'animals'): 'HostPart', ('gut', 'mucosa'): 'HostPart', ('fuel',): 'Environment', ('Ticks',): 'Host', ('infected', 'male', 'embryos'): 'Host', ('louse',): 'Host', ('cavity',): 'HostPart', ('animal',): 'Host', ('Palm', 'Oil'): 'Food', ('researchers',): 'Host', ('females',): 'Host', ('diary', 'products'): 'Food', ('acid', 'mine', 'drainage'): 'Water', ('Texas',): 'Geographical', ('Mauritius',): 'Geographical', ('Egypt',): 'Geographical', ('persons', 'with', 'cystic', 'fibrosis'): 'Host', ('Lycopersicon', 'esculentum'): 'Host', ('fecal', 'leukocytes'): 'HostPart', ('zones',): 'Environment', ('biofilm',): 'Environment', ('laboratory',): 'Environment' ...
# z0
# z1
# z2
# z3
# z4
# z5
# z6
# z7
# z8
# z9
# z10
# z11
# z12
# z13
# z14
# z15
# z16
# z17
# z18
# z new:19
# z19
# z20
# z21
# z22
# z23
# z24
# z25
# i :1
# organs
# z26
# z27
# z28
# z29
# z30
# z31
# z32
# z33
# z34
# i :1
# Pennsylvania
# z35
# z36
# z37
# z38
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :1
# vivo
# z39
# z40
# i :1
# zone
# i :1
# nodules
# z new:41
# z41
# z42
# z43
# z44
# z45
# z46
# i :1
# that
# z47
# z48
# z49
# z50
# z51
# z52
# z53
# z54
# z55
# z56
# z57
# z new:58
# i :1
# end
# i :1
# surface
# z new:59
# z58
# i :1
# wall
# i :1
# end
# i :1
# surface
# z new:59
# z59
# z60
# z new:61
# z61
# z62
# z63
# z64
# z65
# z66
# z67
# z68
# z69
# z70
# z71
# z72
# z73
# z74
# z75
# z76
# z77
# z78
# z79
# z80
# z81
# z82
# z83
# z84
# z85
# z86
# z87
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :1
# vivo
# z88
# i :1
# zone
# i :1
# nodules
# z new:89
# z89
# z90
# z91
# z92
# z93
# z94
# z new:95
# z95
# z96
# i :1
# Pennsylvania
# z97
# i :1
# facilities
# z98
# i :1
# ponds
# i :1
# the
# i :2
# insect
# i :1
# newborn
# i :1
# the
# i :2
# tsetse
# z99
# z100
# z101
# z102
# z103
# z104
# z105
# z106
# z107
# z108
# z109
# z110
# z111
# z112
# z113
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :2
# small
# i :1
# vivo
# z114
# z115
# z116
# i :1
# ponds
# i :1
# the
# i :1
# newborn
# i :1
# the
# z117
# z new:118
# z118
# z119
# z120
# z121
# z122
# z123
# z new:124
# z124
# z125
# z126
# z127
# z128
# z129
# i :1
# zone
# i :1
# nodules
# z new:130
# z130
# z131
# z132
# z133
# z134
# z135
# i :1
# Pennsylvania
# z136
# z137
# z138
# z139
# z140
# z141
# z142
# i :1
# wall
# i :1
# end
# i :1
# surface
# z new:143
# z143
# z144
# z145
# z146
# z147
# z148
# z149
# z new:150
# z150
# z151
# z152
# z153
# z154
# z155
# z156
# i :1
# Pennsylvania
# z157
# z158
# z159
# z160
# z161
# z162
# z163
# z164
# z165
# z166
# z167
# z168
# z169
# z170
# z171
# z new:172
# z172
# z173
# z174
# z175
# z176
# z177
# z178
# z179
# z180
# z181
# z182
# z183
# z184
# z185
# z186
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :1
# vivo
# z187
# z188
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :1
# vivo
# z189
# i :1
# Keys
# i :1
# Reef
# z new:190
# z190
# z191
# z new:192
# z192
# z193
# z194
# z195
# z196
# z197
# z198
# z199
# i :1
# ponds
# i :1
# the
# i :1
# newborn
# i :1
# the
# z200
# z201
# z202
# z203
# z new:204
# z204
# z205
# z206
# z207
# z208
# z209
# z210
# i :1
# organs
# z211
# z212
# z213
# z214
# z215
# z216
# z217
# z218
# z219
# z220
# i :1
# of
# z221
# z222
# z223
# z224
# z225
# z new:226
# z226
# z227
# z228
# i :1
# zone
# i :1
# nodules
# z new:229
# z229
# z230
# z231
# z232
# i :1
# Pennsylvania
# z233
# z new:234
# z234
# z235
# z236
# z237
# z238
# z239
# i :1
# ponds
# i :1
# the
# i :1
# newborn
# i :1
# the
# z240
# z241
# z242
# z243
# z244
# z245
# z246
# z247
# i :1
# Pennsylvania
# z248
# z249
# z250
# z251
# i :1
# ponds
# i :1
# the
# i :1
# newborn
# i :1
# the
# z252
# z253
# z254
# z255
# z256
# z257
# z258
# z259
# z260
# z261
# z262
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :2
# small
# i :1
# vivo
# z263
# z264
# z265
# z266
# z267
# z268
# z269
# z270
# i :1
# ponds
# i :1
# the
# i :1
# newborn
# i :1
# the
# z271
# z272
# z273
# z274
# z275
# z276
# z277
# z278
# z279
# z280
# z281
# z282
# z283
# z284
# z285
# z286
# z287
# z288
# z289
# z290
# z291
# z292
# z293
# z294
# z295
# i :1
# Pennsylvania
# z296
# z297
# z298
# i :1
# ponds
# i :1
# the
# i :2
# insect
# i :1
# newborn
# i :1
# the
# i :2
# tsetse
# z299
# z300
# z301
# z302
# z303
# z304
# z305
# z306
# z307
# z308
# z309
# z310
# z311
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :1
# vivo
# z312
# z new:313
# z313
# z314
# z315
# z316
# z317
# z318
# z319
# z320
# i :1
# of
# i :2
# Glasgow
# z321
# i :1
# ponds
# i :1
# the
# i :1
# newborn
# i :1
# the
# z322
# z323
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :1
# vivo
# z324
# z325
# z326
# z327
# z328
# z329
# z330
# z331
# z332
# z333
# z334
# z335
# z336
# z337
# z338
# i :1
# Europe
# i :1
# vitro
# i :1
# the
# i :1
# vivo
# z339
# z340
# z341
# z342
# z343
# i :1
# ponds
# i :1
# the
# i :2
# insect
# i :1
# newborn
# i :1
# the
# i :2
# tsetse
# z344
# z345
# z346
# z347
# [['Host', 'plant'], ['HostPart', 'root'], ['Host', 'plant'], ['HostPart', 'cell'], ['HostPart', 'cell'], ['Soil', 'nitrogen'], ['HostPart', 'root'], ['HostPart', 'chromosome'], ['Host', 'plant'], ['Host', 'plant'], ['HostPart', 'root'], ['HostPart', 'cell'], ['HostPart', 'membrane'], ['Host', 'plant'], ['Geographical', 'Florida'], ['Geographical', 'USA'], ['Soil', 'nitrogen'], ['Soil', 'nitrogen'], ['HostPart', 'root'], ['HostPart', 'chromosome'], ['Geographical', 'Japan']]

# %%
import nltk,glob
from nltk.tokenize import sent_tokenize, word_tokenize



dirname='/media/DATA/Master/Analyse_donnees_text/data_suj1/dev/'
files=glob.glob(dirname+'*.txt')

for file in files:
#file='/media/DATA/Master/Analyse_donnees_text/data_suj1/dev/BTID-10095.txt'
    with open(file, 'r') as fichier:
        text=fichier.read()
        words=word_tokenize(text, 'english')
        p#rint(words)
        tagged=nltk.pos_tag(words)
        #print(tagged)
        dico = {}
        compteur = 0
        for mot in tagged:
            #print(mot[0])
            if mot[0] == 'in':
                if tagged[compteur+1][1]== 'NN' and tagged[compteur+2][1]== 'NN':
                    print(mot[0] + ' ' +tagged[compteur+1][0] + ' ' + tagged[compteur+2][0])
            compteur += 1
# Out:
# in root nodulation
# in growth mode
# in freshwater medium

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize


#print(d_entities)

file='/media/DATA/Master/Analyse_donnees_text/data_suj1/dev/BTID-10095.txt'
with open(file, 'r') as fichier:
    with open('/media/DATA/Master/Analyse_donnees_text/test1', 'w') as fichier2:
        for line in file:
            text=fichier.read()
            words=word_tokenize(text, 'english')
            for word in words:
                if word in d_entities:
# Out:
#   File "<ipython-input-1-6e477c26ef27>", line 17
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
#import nltk
#nltk.download()

# %% [markdown]
# Extracting localisations by detecting names of countries in the text.

# %%
countries = {}
countries_file = '/media/DATA/Master/Analyse_donnees_text/project_ADT/country_names'
with open(countries_file, 'r') as c_file:
    for line in c_file:
        country = line.rstrip('\n')
        taille = len(country.split())
        if taille in countries:
            countries[taille].append(country)
        else:
            countries[taille] = [country]

#print(countries)
# Out:
# {1: ['Andorra', 'Afghanistan', 'Anguilla', 'Albania', 'Armenia', 'Angola', 'Antarctica', 'Argentina', 'Austria', 'Australia', 'Aruba', 'Azerbaijan', 'Barbados', 'Bangladesh', 'Belgium', 'Bulgaria', 'Bahrain', 'Burundi', 'Benin', 'Bermuda', 'Brunei', 'Bolivia', 'Brazil', 'Bahamas', 'Bhutan', 'Botswana', 'Belarus', 'Belize', 'Canada', 'Switzerland', 'Chile', 'Cameroon', 'China', 'Colombia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Denmark', 'Dominica', 'Algeria', 'Ecuador', 'Estonia', 'Egypt', 'Eritrea', 'Spain', 'Ethiopia', 'Finland', 'Fiji', 'Micronesia', 'France', 'Gabon', 'Grenada', 'Georgia', 'Guernsey', 'Ghana', 'Gibraltar', 'Greenland', 'Gambia', 'Guinea', 'Guadeloupe', 'Greece', 'Guatemala', 'Guam', 'Guinea-Bissau', 'Guyana', 'Honduras', 'Croatia', 'Haiti', 'Hungary', 'Indonesia', 'Ireland', 'Israel', 'India', 'Iraq', 'Iran', 'Iceland', 'Italy', 'Jersey', 'Jamaica', 'Jordan', 'Japan', 'Kenya', 'Kyrgyzstan', 'Cambodia', 'Kiribati', 'Comoros', 'Kosovo', 'Kuwait', 'Kazakhstan', 'Laos', 'Lebanon', 'Liechtenstein', 'Liberia', 'Lesotho', 'Lithuania', 'Luxembourg', 'Latvia', 'Libya', 'Morocco', 'Monaco', 'Moldova', 'Montenegro', 'Madagascar', 'Macedonia', 'Mali', 'Myanmar', 'Mongolia', 'Macao', 'Martinique', 'Mauritania', 'Montserrat', 'Malta', 'Mauritius', 'Maldives', 'Malawi', 'Mexico', 'Malaysia', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Nicaragua', 'Netherlands', 'Norway', 'Nepal', 'Nauru', 'Niue', 'Oman', 'Panama', 'Peru', 'Philippines', 'Pakistan', 'Poland', 'Pitcairn', 'Portugal', 'Palau', 'Paraguay', 'Qatar', 'Reunion', 'Romania', 'Serbia', 'Russia', 'Rwanda', 'Seychelles', 'Sudan', 'Sweden', 'Singapore', 'Slovenia', 'Slovakia', 'Senegal', 'Somalia', 'Suriname', 'Syria', 'Swaziland', 'Chad', 'Togo', 'Thailand', 'Tajikistan', 'Tokelau', 'Turkmenistan', 'Tunisia', 'Tonga', 'Turkey', 'Tuvalu', 'Taiwan', 'Tanzania', 'Ukraine', 'Uganda', 'Uruguay', 'Uzbekistan', 'Vatican', 'Venezuela', 'Vietnam', 'Vanuatu', 'Samoa', 'Yemen', 'Mayotte', 'Zambia', 'Zimbabwe'], 2: ['American Samoa', 'Aland Islands', 'Burkina Faso', 'Saint Barthelemy', 'Bouvet Island', 'Cocos Islands', 'Ivory Coast', 'Cook Islands', 'Costa Rica', 'Cape Verde', 'Christmas Island', 'Dominican Republic', 'Western Sahara', 'Falkland Islands', 'Faroe Islands', 'United Kingdom', 'French Guiana', 'Equatorial Guinea', 'Hong Kong', 'North Korea', 'South Korea', 'Cayman Islands', 'Saint Lucia', 'Sri Lanka', 'Saint Martin', 'Marshall Islands', 'New Caledonia', 'Norfolk Island', 'New Zealand', 'French Polynesia', 'Puerto Rico', 'Palestinian Territory', 'Saudi Arabia', 'Solomon Islands', 'South Sudan', 'Saint Helena', 'Sierra Leone', 'San Marino', 'El Salvador', 'Sint Maarten', 'East Timor', 'United States', 'South Africa', 'Netherlands Antilles'], 3: ['United Arab Emirates', 'Antigua and Barbuda', 'Bosnia and Herzegovina', 'Central African Republic', 'Isle of Man', 'Northern Mariana Islands', 'Papua New Guinea', 'French Southern Territories', 'Trinidad and Tobago', 'British Virgin Islands', 'U.S. Virgin Islands', 'Wallis and Futuna', 'Serbia and Montenegro'], 4: ['Republic of the Congo', 'British Indian Ocean Territory', 'Saint Kitts and Nevis', 'Saint Pierre and Miquelon', 'Svalbard and Jan Mayen', 'Sao Tome and Principe', 'Turks and Caicos Islands'], 5: ['Bonaire, Saint Eustatius and Saba ', 'Democratic Republic of the Congo', 'Heard Island and McDonald Islands', 'United States Minor Outlying Islands', 'Saint Vincent and the Grenadines'], 7: ['South Georgia and the South Sandwich Islands']}

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

localisations = []
file='/media/DATA/Master/Analyse_donnees_text/data_suj1/dev/BTID-10095.txt'
with open(file, 'r') as fichier:
    with open('/media/DATA/Master/Analyse_donnees_text/test1', 'w') as fichier2:
        for line in file:
            text=fichier.read()
            words=word_tokenize(text, 'english')
            for word in words:
                if word in countries[1]:
                    localisations.append(word)
print(localisations)
# Out:
# ['Japan']
